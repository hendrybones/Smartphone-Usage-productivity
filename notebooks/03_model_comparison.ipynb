# %% [markdown]
# #### Importing Functions

# %%
import sys
sys.path.append("../src/models")

from model_comparison import load_config, load_data, prepare_data, compare_models

# Load config
config = load_config("../config/config.yaml")

# %% [markdown]
# ### Load Data

# %%
# Load dataset
df = load_data(config)

df.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[5], line 2
#       1 # Load dataset
# ----> 2 df = load_data(config)
#       4 df.head()
#
# File c:\Users\Administrator\OneDrive\Documents\Data Science\Smartphone-Usage-productivity\notebooks\../src/models\model_comparison.py:32, in load_data(config)
#      30 """Load preprocessed features dataset."""
#      31 # Use the correct key from your YAML
# ---> 32 data_path = Path(config['data']['processed']) / "features.parquet"
#      34 logging.info(f"Loading data → {data_path}")
#      35 df = pd.read_parquet(data_path)
#
# KeyError: 'processed'
